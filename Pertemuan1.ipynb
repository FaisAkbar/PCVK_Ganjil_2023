# %% [markdown]
# <a href="https://colab.research.google.com/github/FaisAkbar/PCVK_Ganjil_2023/blob/main/Pertemuan1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### MODUL 1 – Penggunaan Github dan Google Colaboratory, Membaca dan Menampilkan Citra
# ### Nama : Fawaa'el Akbar Firdaus
# ### No : 10
# ### NIM : 2141720215
# ### Kelas : TI-3B

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/571"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                          #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  #conver color to RGB
  final_frame = cv.hconcat((image, image_2))      #Concatenate image
  cv2_imshow(final_frame)                         #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ", tinggi, " x ", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# #Pertanyaan
#
#
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?
# ##### Jawaban : Google Colab (singkatan dari Google Colaboratory) adalah sebuah platform yang disediakan oleh Google untuk pengembangan dan eksekusi kode Python secara online. Colab memungkinkan Anda menulis dan menjalankan kode Python melalui browser web tanpa perlu menginstal atau mengatur lingkungan pengembangan lokal
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
# ##### Jawaban : tidak semua library digunakan pada praktikum sesi ini
# *   numpy (np): Digunakan untuk komputasi numerik dan operasi matematika pada array multidimensional.
# *   pandas (pd): Berguna untuk analisis dan manipulasi data tabular dengan DataFrame.
# *   cv2 (OpenCV): Spesialis dalam pemrosesan citra dan penglihatan komputer.
# *   google.colab.patches.cv2_imshow: Untuk menampilkan gambar dalam Google Colab yang diolah dengan OpenCV.
# *   skimage.io (skimage): Digunakan untuk membaca, menyimpan, dan melakukan operasi pada citra.
# *   skimage.transform: Berisi fungsi untuk melakukan transformasi pada citra.
# *   PIL (Python Imaging Library): Untuk manipulasi dan pengolahan citra.
# *   matplotlib.pylab (plt): Untuk membuat visualisasi data dan grafik.
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut : Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
# ##### Jawaban : Hasil dari program ini adalah citra "image" yang telah diubah ukurannya menjadi setengah dari ukuran aslinya baik dalam lebar maupun tinggi. Dengan demikian, citra tersebut akan menjadi lebih kecil tetapi masih mempertahankan proporsi aslinya.
# *   cv.resize(image, (0,0), fx=0.5, fy=0.5) : Fungsi ini digunakan untuk mengubah ukuran citra yang disimpan dalam variabel "image".
# *   image : Variabel yang berisi citra yang ingin diubah ukurannya.
# *   (0,0) : Ukuran target baru dalam format (lebar, tinggi). Dalam kasus ini (0,0) digunakan untuk mengizinkan pengubahan skala citra tanpa mengubah proporsi aslinya.
# *   fx=0.5, fy=0.5 : Parameter fx dan fy adalah faktor skala untuk mengubah ukuran citra. Dalam kasus ini, citra akan diubah menjadi setengah ukuran aslinya, baik dalam lebar (fx) maupun tinggi (fy).
# 4. Perhatikan potongan kode progam berikut : Apakah kegunaan kode [255,255,255] ? Jelaskan!
# ##### Jawaban : kegunaan kode [255,255,255] adalah untuk mengisi piksel dengan warna putih dan membuat garis horizontal putih di tengah citra image_3
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
# ##### Jawaban : Pixel (singkatan dari "picture element") adalah unit terkecil dalam representasi digital dari gambar. Resolusi tinggi memiliki lebih banyak pixel, memberikan detail lebih baik, cocok untuk pencetakan besar. Resolusi rendah memiliki lebih sedikit pixel, cocok untuk tampilan kecil di layar, memungkinkan penyimpanan kecil. Jumlah pixel memengaruhi kualitas dan detail gambar.

# %% [markdown]
# # Tugas
#
#
# 1.  Lakukan langkah-langkah praktikum seperti diatas
# 2.	Buat garis vertikal dan garis menyilang diagonal pada image keluaran
# 3.	Buat garis horisontal berwarna putih dibagian tengah gambar dengan panjang tertentu
# 4.	Buat kotak menggunakan kumpulan pixel warna putih di sembarang tempat dalam gambar

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_4 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_5 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat garis vertikal ditengah image
for x in range (tinggi):
  image_2[x,int((lebar)/2)] = [255,255,255]

# Membuat garis menyilang ditengah image
# Menghitung tinggi dari garis miring
garismiring = int(np.sin(np.deg2rad(45)) * lebar)
# Membuat garis miring di tengah citra
for x in range(lebar):
    y = int((tinggi - garismiring) / 2 + np.sin(np.deg2rad(45)) * x)
    if 0 <= y < tinggi:
        image_3[y, x] = [255, 255, 255]
# Menghitung tinggi dari garis miring
garismiring = int(np.sin(np.deg2rad(-45)) * lebar)
# Membuat garis miring di tengah citra
for x in range(lebar):
    y = int((tinggi - garismiring) / 2 + np.sin(np.deg2rad(-45)) * x)
    if 0 <= y < tinggi:
        image_3[y, x] = [255, 255, 255]

# Membuat garis horisontal berwarna putih dibagian tengah gambar dengan panjang tertentu
# Panjang garis yang diinginkan (misalnya, setengah lebar citra)
panjang_garis = 50
# Tinggi garis di tengah citra
y_pos = tinggi // 2
# Koordinat awal dan akhir garis horizontal
x_awal = (lebar - panjang_garis) // 2
x_akhir = x_awal + panjang_garis
cv.line(image_4, (x_awal, y_pos), (x_akhir, y_pos), [255,255,255], 1)

# Membuat kotak menggunakan kumpulan pixel warna putih di sembarang tempat dalam gambar
# Ukuran kotak (misalnya, lebar 50 piksel, tinggi 30 piksel)
kotak_lebar = 50
kotak_tinggi = 45
# Lokasi kotak (koordinat kiri atas, misalnya, x=100, y=100)
x_awal = 150
y_awal = 100
for y in range(y_awal, y_awal + kotak_tinggi):
    for x in range(x_awal, x_awal + kotak_lebar):
        image_5[y, x] = [255,255,255]

# Menampilkan semua gambar
final_frame = cv.hconcat((image_2, image_3, image_4, image_5))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x286>

# %% [markdown]
# # Tugas Kelompok
#
# Bentuk kelompok masing-masing terdiri dari 2-3 orang. tiap kelompok lakukan langkah berikut
# 1.  Akses file image lokal (KTP/SIM) dan tampilkan menggunakan OpenCV dan Matplotlib
# 2.	Identifikasi kenapa menggunakan konversi warna BGR2RGB pada matplotlib dan tanpa konversi pada opencv
# 3.	Tutup tiap bagian tertentu dari kartu identitas tersebut. Kelompok 1 tutup bagian nomor NIK dan nama. Kelompok 2 tutup bagian TTL dan Jenis Kelamin. Kelompok 3 tutup bagian Gol. Darah dan TTD. Kelompok 4 tutup bagian Alamat dan Kecamatan. Kelompok 5 tutup bagian Agama dan Status Kawin. Kelompok 6 tutup Pekerjaan dan kewarganegaraan. Kelompok 7 tutup bagian berlaku hingga dan foto. Kelompok 8 tutup bagian kabupaten dan tanggal dikeluarkan KTP yang ada dibagian bawah foto. Kelompok 9 tutup bagian nama propinsi dan kabupaten di bagian paling atas KTP. Kelompok 10 tutup bagian RT/RW dan Kel/desa. Tutup menggunakan 2 kotak warna yang berbeda. Tidak boleh menggunakan fungsi rectangle openCV, fungsi ini akan dipelajari pada pertemuan 2.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
image_6 = cv.imread('/content/drive/MyDrive/PCVK/P1/KTP.jpeg')
image_7 = cv.cvtColor(image_6, cv.COLOR_BGR2RGB)
cv2_imshow(image_6)
plt.imshow(image_7)
# Out:
# <PIL.Image.Image image mode=RGB size=800x488>

# %%
image_nama = np.copy(image_6)
#tutup bagian nama
for y in range (190,450):
  for x in range (120,140):
    image_nama[x,y] = [0,0,0]

#tutup bagian NIK
image_nik = np.copy(image_nama)
for y in range (190,550):
  for x in range (70,100):
    image_nik[x,y] = [0,255,255]

#tutup bagian alamat
image_alamat = np.copy(image_nik)
for y in range (190,390):
  for x in range (190,210):
    image_alamat[x,y] = [0,180,50]

#tutup bagian tanda tangan
image_ttd = np.copy(image_alamat)
for y in range (600,750):
  for x in range (420,480):
    image_ttd[x,y] = [0,0,255]

#tutup bagian mata
image_mata = np.copy(image_ttd)
for y in range (600,750):
  for x in range (190,210):
    image_mata[x,y] = [255,0,0]

#tutup bagian Agama
image_agama = np.copy(image_mata)
for y in range (190,250):
  for x in range (280,300):
    image_agama[x,y] = [50,150,20]

# final_frame = cv.hconcat((image_6, image_nik, image_alamat, image_ttd, image_mata, image_agama))
final_frame = cv.hconcat((image_6, image_agama))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x488>

# %% [markdown]
# OpenCV: Warna BGR (Blue-Green-Red) sebagai representasi default untuk gambar berwarna. Jadi nilai pixel pertama adalah biru, yang kedua adalah  hijau, dan yang ketiga adalah merah.
#
# Matplotlib: Warna RGB (Red-Green-Blue) sebagai representasi default. Jadi nilai pixel pertama adalah merah, yang kedua adalah hijau, dan yang ketiga adalah biru.
#
# Jadi perlu dilakukan kenversi warna jika ingin memplot gambar dari OpenCV ke Matplotlib
